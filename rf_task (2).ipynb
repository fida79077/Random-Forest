# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/MECHINE LEARNING/ML Algorithm/Random Forest Algorithm/car_evaluation.csv')

# %%
df.head()
# Out:
#    vhigh vhigh.1  2 2.1  small   low  unacc
# 0  vhigh   vhigh  2   2  small   med  unacc
# 1  vhigh   vhigh  2   2  small  high  unacc
# 2  vhigh   vhigh  2   2    med   low  unacc
# 3  vhigh   vhigh  2   2    med   med  unacc
# 4  vhigh   vhigh  2   2    med  high  unacc

# %%
df.shape
# Out:
# (1727, 7)

# %% [markdown]
# Rename Coumn Names

# %%
col_names = ['buying','maint','doors','persons','1 ug_boot','safety','class']

df.columns = col_names

col_names
# Out:
# ['buying', 'maint', 'doors', 'persons', '1 ug_boot', 'safety', 'class']

# %%
df.head()
# Out:
#   buying  maint doors persons 1 ug_boot safety  class
# 0  vhigh  vhigh     2       2     small    med  unacc
# 1  vhigh  vhigh     2       2     small   high  unacc
# 2  vhigh  vhigh     2       2       med    low  unacc
# 3  vhigh  vhigh     2       2       med    med  unacc
# 4  vhigh  vhigh     2       2       med   high  unacc

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727 entries, 0 to 1726
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   buying     1727 non-null   object
#  1   maint      1727 non-null   object
#  2   doors      1727 non-null   object
#  3   persons    1727 non-null   object
#  4   1 ug_boot  1727 non-null   object
#  5   safety     1727 non-null   object
#  6   class      1727 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %%
df.isnull().sum()
# Out:
# buying       0
# maint        0
# doors        0
# persons      0
# 1 ug_boot    0
# safety       0
# class        0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for i in df.columns:
  df[i] = le.fit_transform(df[i])

# %%
x = df.drop(['class'], axis=1)

y = df['class']

# %%
x
# Out:
#       buying  maint  doors  persons  1 ug_boot  safety
# 0          3      3      0        0          2       2
# 1          3      3      0        0          2       0
# 2          3      3      0        0          1       1
# 3          3      3      0        0          1       2
# 4          3      3      0        0          1       0
# ...      ...    ...    ...      ...        ...     ...
# 1722       1      1      3        2          1       2
# 1723       1      1      3        2          1       0
# 1724       1      1      3        2          0       1
# 1725       1      1      3        2          0       2
# 1726       1      1      3        2          0       0
#
# [1727 rows x 6 columns]

# %%
y
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1722    1
# 1723    3
# 1724    2
# 1725    1
# 1726    3
# Name: class, Length: 1727, dtype: int64

# %% [markdown]
# split data into training and testing sets

# %%
from sklearn.model_selection import train_test_split

x_train, x_test , y_train , y_test = train_test_split(x, y ,test_size = 0.33 , random_state = 42)

# %%
x_train.shape , x_test.shape
# Out:
# ((1157, 6), (570, 6))

# %%
x_train.dtypes
# Out:
# buying       int64
# maint        int64
# doors        int64
# persons      int64
# 1 ug_boot    int64
# safety       int64
# dtype: object

# %%
x_train.head()
# Out:
#       buying  maint  doors  persons  1 ug_boot  safety
# 83         3      3      3        0          1       1
# 48         3      3      1        2          1       2
# 468        0      3      1        1          2       2
# 155        3      0      1        2          1       1
# 1043       2      0      2        2          2       1

# %%
x_test.head()
# Out:
#       buying  maint  doors  persons  1 ug_boot  safety
# 599        0      0      2        0          0       1
# 932        2      3      2        1          0       1
# 628        0      0      3        0          0       0
# 1497       1      0      3        1          1       2
# 1262       2      1      2        2          1       1

# %%
#import random forest classifier
from sklearn.ensemble import RandomForestClassifier

#instantiate the classifiet
rfc = RandomForestClassifier(random_state=0)

#fit the model
rfc.fit(x_train , y_train)

#predict the test set result
y_pred = rfc.predict(x_test)

#check accuracy score
from sklearn.metrics import accuracy_score

print('Model accuracy score with 10decision trees : {0:0.4f}'.format(accuracy_score(y_test , y_pred)))
# Out:
# Model accuracy score with 10decision trees : 0.9579
